# %%
import seaborn as sb
import pandas as pn

people = pn.read_csv('people.csv', delimiter=';')
#tips = sb.load_dataset('tips')

people.head()
# Out:
#     name                 job sex  age  salary
# 0   Juan  Software Developer   M   24   85000
# 1   John             Manager   M   42  140000
# 2  Peter       Data Engineer   M   42  110000
# 3  Deivi  Software Developer   M   23   85000
# 4    Ana     Front Developer   F   28   95000

# %%
sb.barplot(x='sex', y='salary', data=people)

# %%
sb.countplot(x='sex', data = people)

# %%
sb.boxplot(x = 'job',y = 'salary' , data=people, hue='sex')

# %%
sb.violinplot(x = 'job',y = 'salary' , data=people, hue='sex', split = True)

# %%
sb.stripplot(x = 'job',
             y = 'salary', 
             data = people, 
             jitter = True, 
             hue = 'sex', 
             dodge = True)

# %%
sb.swarmplot(x = 'job',
             y = 'salary', 
             data = people,
             size = 6)

# %%
sb.factorplot(x = 'job',
              y = 'salary', 
              data = people,
              kind = 'bar', 
              size = 6
             )
