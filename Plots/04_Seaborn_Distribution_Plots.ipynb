# %%
import seaborn as sb
import pandas as pn

people = pn.read_csv('people.csv', delimiter=';')

people.head()
# Out:
#       name                 job sex  age  salary
# 0   Antony  Software Developer   M   23   72000
# 1  Manuela  Software Developer   M   24   72000
# 2    Homer     Front Developer   M   31   87600
# 3    David  Software Developer   M   33   82000
# 4    David  Software Developer   M   33   83000

# %%
sb.distplot(people['salary'], 
            hist_kws=dict(edgecolor="blue"),
              # definition
            kde = True) # curve

# %%
sb.kdeplot(people['salary'])

# %%
sb.jointplot(x='salary',
             y='age', 
             data = people,
             kind = 'kde') # hex, reg, kde

# %%
sb.pairplot(people,
            palette = 'coolwarm',
            hue = 'sex') # Using categorical field

# %%
sb.rugplot(people['salary'])
