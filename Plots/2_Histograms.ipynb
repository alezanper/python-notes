# %%
# pyplot is a library for plotting
import matplotlib.pyplot as pt
import numpy as np

# Creating random data
data = np.random.randn(300)

# Plotting simple data
pt.hist(data)
pt.show()

# %%
# pyplot is a library for plotting
import matplotlib.pyplot as pt
import numpy as np

# Creating random data
data = np.random.randn(300)

# Adding edgecolor 
pt.hist(data, edgecolor='black')
pt.show()

# %%
# pyplot is a library for plotting
import matplotlib.pyplot as pt
import numpy as np

# Creating random data
data = np.random.randn(300)

# Creating Titles
xTitle = 'X - Axis'
yTitle = 'Y - Axis' 
title = 'Title'

# Adding titles to plot
pt.hist(data, edgecolor='black')
pt.xlabel(xTitle)
pt.ylabel(yTitle)
pt.title(title)

# Adding grid
pt.grid()

pt.show()
